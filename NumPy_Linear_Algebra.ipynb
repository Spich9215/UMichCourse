# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %%
import numpy as np

# %%
b1 = np.array([1,1])
b2 = np.array([1,-1])
v = np.array([5,-1])

# %%
np.linalg.inv(np.array([b1, b2])).dot(v)
# Out:
# array([2., 3.])

# %%
np.array([b1, b2])
# Out:
# array([[ 1,  1],
#        [ 1, -1]])

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
np.linalg.inv(np.array([b1, b2]))
# Out:
# array([[ 0.5,  0.5],
#        [ 0.5, -0.5]])

# %%
np.linalg.inv(np.array([b1, b2])).dot(np.array([5,-1]))
# Out:
# array([2., 3.])

# %%
np.linalg.inv(np.array([[3, 4], [4, -3]])).dot(np.array([10,-5]))
# Out:
# array([0.4, 2.2])

# %%
np.linalg.inv(np.array([[-3, 1], [1, 3]])).dot(np.array([2,2]))
# Out:
# array([-0.4,  0.8])

# %%
np.array([[2, 1, 0], [1, -2, -1], [-1, 2, -5]])
# Out:
# array([[ 2,  1,  0],
#        [ 1, -2, -1],
#        [-1,  2, -5]])

# %%
np.linalg.inv(np.array([[2, 1, 0], [1, -2, -1], [-1, 2, -5]]))
# Out:
# array([[ 0.4       ,  0.16666667, -0.03333333],
#        [ 0.2       , -0.33333333,  0.06666667],
#        [-0.        , -0.16666667, -0.16666667]])

# %%
np.linalg.inv(np.array([[2, 1, 0], [1, -2, -1], [-1, 2, -5]])).dot(np.array([1,1,1]))
# Out:
# array([ 0.53333333, -0.06666667, -0.33333333])

# %%
np.linalg.inv(np.array([[1, 0, 0, 0], [0, 2, -1, 0], [0, 1, 2, 0], [0, 0,0,3]])).dot(np.array([1,1,2,3]))
# Out:
# array([1. , 0.8, 0.6, 1. ])
